# %% [markdown]
# ## UK House Price Index Analysis

# %% [markdown]
# ### Introduction: I used UK house price index data for my data analysis project. The goal of this project is to analyse the price behaviour of residential properties in London. The variables of interest are house prices in the city of London and outskirs of London. I have specifically coosen the 'Average price' sheet from the dataset.

# %% [markdown]
# ### Importing Libraries

# %%
#Required for data analysis
import pandas as pd
import numpy as np

#Required for data visualisation
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.offline import plot, iplot

# %%
# !pip install folium

# %%
import folium
import re

# %% [markdown]
# ### Loading the dataset

# %%
df = pd.read_excel (r'C:\Users\ishwa\SDPA-resit\Part 1\UK House price index.xlsx', sheet_name='Average price')
df
# Out:
#     Unnamed: 0 City of London Barking & Dagenham       Barnet       Bexley  \
# 0          NaT      E09000001          E09000002    E09000003    E09000004
# 1   1995-01-01    91448.98487         50460.2266  93284.51832  64958.09036
# 2   1995-02-01    82202.77314        51085.77983  93190.16963  64787.92069
# 3   1995-03-01    79120.70256        51268.96956  92247.52435  64367.49344
# 4   1995-04-01    77101.20804        53133.50526  90762.87492  64277.66881
# ..         ...            ...                ...          ...          ...
# 324 2021-12-01     813435.102        329557.0047  583195.3087  379526.3458
# 325 2022-01-01    811508.8041        338869.7029  580179.6373  382270.4215
# 326 2022-02-01     864897.234        345001.3576  576485.8755  387171.1018
# 327 2022-03-01    813511.6177        346064.5259  576689.7495  393246.1533
# 328 2022-04-01    838145.2394        336125.8982  596898.1846  392154.9821
#
# ...

# %% [markdown]
# ### Data Preparation and Cleaning

# %% [markdown]
# ### Once we have the data in front of us we will rename the columns, perform descriptive statistics to better understand the dataset's features, find null values, and remove unnecessary rows and columns.

# %%
#Adding the column name
df.rename(columns={"Unnamed: 0":"Date"})
# Out:
#           Date City of London Barking & Dagenham       Barnet       Bexley  \
# 0          NaT      E09000001          E09000002    E09000003    E09000004
# 1   1995-01-01    91448.98487         50460.2266  93284.51832  64958.09036
# 2   1995-02-01    82202.77314        51085.77983  93190.16963  64787.92069
# 3   1995-03-01    79120.70256        51268.96956  92247.52435  64367.49344
# 4   1995-04-01    77101.20804        53133.50526  90762.87492  64277.66881
# ..         ...            ...                ...          ...          ...
# 324 2021-12-01     813435.102        329557.0047  583195.3087  379526.3458
# 325 2022-01-01    811508.8041        338869.7029  580179.6373  382270.4215
# 326 2022-02-01     864897.234        345001.3576  576485.8755  387171.1018
# 327 2022-03-01    813511.6177        346064.5259  576689.7495  393246.1533
# 328 2022-04-01    838145.2394        336125.8982  596898.1846  392154.9821
#
# ...
